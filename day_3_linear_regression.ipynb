# %% [markdown]
# <a href="https://colab.research.google.com/github/kavithabantupalli/linear-regression/blob/main/day_3_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linear
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/delivery_time.csv')
df
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
# prompt: renamming

df.rename(columns={'Delivery Time':'Delivery_time','Sorting Time':'Sorting_Time'}, inplace=True)
df
# Out:
#     delivery_time  Sorting_Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
# prompt: info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   delivery_time  21 non-null     float64
#  1   Sorting_Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
# prompt: nunique

df.nunique()
# Out:
# delivery_time    21
# Sorting_Time      9
# dtype: int64

# %%
# prompt: describe

df.describe()
# Out:
#        delivery_time  Sorting_Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
# prompt: iloc
x=df.iloc[:,:-1].values#independent variable array
y=df.iloc[:,1].values#dependent variable vector

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test =train_test_split(x,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred =regressor.predict(X_test)
y_pred
# Out:
# array([6.78676086, 4.20800625, 8.23731033, 5.01386706, 3.90580844,
#        7.56441655, 4.42155936])

# %%
Y_test
# Out:
# array([10,  3,  5,  4,  4,  8,  3])

# %%
#plot for the TRAIN
plt.scatter(X_train,Y_train,color='cyan')#plotting the observation line
plt.plot(X_train, regressor.predict(X_train),color='darkblue') #plotting the regression line
plt.title("Sorting time vs Delivery time (Train set)")#starting the title of the plot
plt.xlabel("Delivery_Time")
plt.ylabel("Sorting_Time")
plt.show()

# %%
#plot for the TEST
plt.scatter(X_test,Y_test,color='orange')#plotting the observation line
plt.plot(X_train, regressor.predict(X_train),color='yellow') #plotting the regression line
plt.title("Sorting time vs Delivery time (Train set)")#starting the title of the
plt.xlabel("Delivery_Time")
plt.ylabel("Sorting_Time")
plt.show()
